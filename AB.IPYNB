# %%
import os

# %%
ab=os.environ.get('DAGSHUB_TOKEN')

# %%
print(ab)
# Out:
# None

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
print(os.environ.get('DAGSHUB_TOKEN'))
# Out:
# 8a363a53d651110c6245fb7d25a639b2d59f64a7
